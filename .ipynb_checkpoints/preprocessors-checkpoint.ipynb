# %%
#pip install -U pip setuptools wheel
# Out:
# Requirement already satisfied: pip in c:\users\asaines\anaconda3\lib\site-packages (22.2.2)
# Requirement already satisfied: setuptools in c:\users\asaines\anaconda3\lib\site-packages (65.3.0)
# Requirement already satisfied: wheel in c:\users\asaines\anaconda3\lib\site-packages (0.37.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install -U spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.4.1-cp39-cp39-win_amd64.whl (11.8 MB)
#      ---------------------------------------- 11.8/11.8 MB 3.5 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.3-py3-none-any.whl (9.3 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.6-cp39-cp39-win_amd64.whl (36 kB)
# Requirement already satisfied: jinja2 in c:\users\asaines\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.10-py2.py3-none-any.whl (21 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4
#   Downloading pydantic-1.9.2-cp39-cp39-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 4.2 MB/s eta 0:00:00
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.2-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.8/42.8 kB ? eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\asaines\anaconda3\lib\site-packages (from spacy) (65.3.0)
# Collecting thinc<8.2.0,>=8.1.0
#   Downloading thinc-8.1.1-cp39-cp39-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 5.4 MB/s eta 0:00:00
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy) (2.27.1)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.7-cp39-cp39-win_amd64.whl (96 kB)
#      ---------------------------------------- 96.8/96.8 kB 5.8 MB/s eta 0:00:00
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.8-cp39-cp39-win_amd64.whl (18 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy) (4.64.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy) (21.3)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.4-cp39-cp39-win_amd64.whl (450 kB)
#      -------------------------------------- 450.1/450.1 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asaines\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Collecting smart-open<6.0.0,>=5.2.1
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\asaines\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy) (4.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asaines\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asaines\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asaines\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asaines\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.1-py3-none-any.whl (32 kB)
# Collecting blis<0.10.0,>=0.7.8
#   Downloading blis-0.9.1-cp39-cp39-win_amd64.whl (7.4 MB)
#      ---------------------------------------- 7.4/7.4 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\asaines\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\asaines\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\asaines\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: wasabi, cymem, spacy-loggers, spacy-legacy, smart-open, pydantic, murmurhash, langcodes, catalogue, blis, typer, srsly, preshed, pathy, confection, thinc, spacy
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 5.1.0
#     Uninstalling smart-open-5.1.0:
#       Successfully uninstalled smart-open-5.1.0
# Successfully installed blis-0.9.1 catalogue-2.0.8 confection-0.0.1 cymem-2.0.6 langcodes-3.3.0 murmurhash-1.0.8 pathy-0.6.2 preshed-3.0.7 pydantic-1.9.2 smart-open-5.2.1 spacy-3.4.1 spacy-legacy-3.0.10 spacy-loggers-1.0.3 srsly-2.4.4 thinc-8.1.1 typer-0.4.2 wasabi-0.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#!python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.0/en_core_web_sm-3.4.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 12.8/12.8 MB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\asaines\anaconda3\lib\site-packages (from en-core-web-sm==3.4.0) (3.4.1)
# Requirement already satisfied: setuptools in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (65.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (21.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.6.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.10)
# Requirement already satisfied: jinja2 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.11.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.0.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.9.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.64.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.27.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.4.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (8.1.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.0.8)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\asaines\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asaines\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\asaines\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\asaines\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asaines\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asaines\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asaines\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asaines\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\asaines\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.0.1)
# Requirement already satisfied: blis<0.10.0,>=0.7.8 in c:\users\asaines\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.9.1)
# Requirement already satisfied: colorama in c:\users\asaines\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\asaines\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\asaines\anaconda3\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.4.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import spacy
import re


class BasicPreprocess:
    def __init__(self, model: str = "en_core_web_md", **params):
        """
        :param model: model name from spacy
        :param params:
        """
        self.params = params
        self.nlp = spacy.load(model)

    def __call__(self, text) -> str:
        raise NotImplemented


class AdvancedPreprocess:
    def __init__(self, model: str = "en_core_web_md", **params):
        """
        :param model: model name from spacy
        :param params:
        """
        self.params = params
        self.nlp = spacy.load(model)

    def __call__(self, text) -> list:
        raise NotImplemented


class RemoveStopwords(BasicPreprocess):
    def __init__(self, model: str = "en_core_web_md", **params):
        super(RemoveStopwords, self).__init__(model, **params)

    def __call__(self, text: str, **params) -> str:
        return " ".join(str(item) for item in [token for token in self.nlp(text) if not token.is_stop]).strip()


class Lemmatize(BasicPreprocess):
    def __init__(self, model: str = "en_core_web_md", **params):
        super(Lemmatize, self).__init__(model, **params)

    def __call__(self, text: str, **params) -> str:
        return " ".join(str(item) for item in [token.lemma_ for token in self.nlp(text)])


class RemovePunctuation(BasicPreprocess):
    def __init__(self, model: str = "en_core_web_md", **params):
        super(RemovePunctuation, self).__init__(model, **params)

    def __call__(self, text: str, **params) -> str:
        return " ".join(str(item) for item in [token for token in self.nlp(text) if not token.is_punct]).strip()


class Lower(BasicPreprocess):
    def __init__(self, model: str = "en_core_web_md", **params):
        super(Lower, self).__init__(model, **params)

    def __call__(self, text: str, **params) -> str:
        return " ".join(str(item) for item in [token.lower_ for token in self.nlp(text)])


class Sentensize(AdvancedPreprocess):
    def __init__(self, model: str = "en_core_web_md", **params):
        super(Sentensize, self).__init__(model, **params)

    def __call__(self, text: str, **params) -> list:
        return list(self.nlp(text).sents)


class RemoveExtras(BasicPreprocess):
    def __init__(self, model: str = "en_core_web_md", **params):
        super(RemoveExtras, self).__init__(model, **params)

    def __call__(self, text: str) -> str:
        result = text.strip()
        result = result.replace("AAm\nmeerriiccaannRRhheettoorriicc..ccoom\nm", "").replace(
            "Property of AmericanRhetoric.com", "").replace(
            "Property of  AmericanRhetoric.com", "")

        result = result.replace("AmericanRhetoric.com", "")
        result = re.sub("Copyright Status: ([a-zA-Z]+( [a-zA-Z]+)+)\.", "", result)
        result = re.sub("©Copyright\s[0-9]+\. ([a-zA-Z]+( [a-zA-Z]+)+)\.", "", result)
        result = re.sub("Copyright Status: [a-zA-Z]+, [a-zA-Z]+ [a-zA-Z]+\.", "", result)
        result = re.sub("Copyright Status = [a-zA-Z]+\s[a-zA-Z]+", "", result)
        result = re.sub("Copyright Status = [a-zA-Z]+", "", result)
        result = re.sub("Copyright Status: [a-zA-Z]+", "", result)


        result = re.sub("[a-zA-Z]+ by [a-zA-Z]+ [a-zA-Z]\. [a-zA-Z]+ [a-zA-Z]+", "", result)
        result = re.sub("[a-zA-Z]+ by [a-zA-Z]+ [a-zA-Z]\. [a-zA-Z]+\.", "", result)
        result = re.sub("[a-zA-Z]+ by [a-zA-Z]+ [a-zA-Z]\. [a-zA-Z]+", "", result)
        result = re.sub("[a-zA-Z]+ by [a-zA-Z]+ [a-zA-Z]+\.", "", result)
        result = re.sub("[a-zA-Z]+ by [a-zA-Z]+ [a-zA-Z]+ [a-zA-Z]+ [a-zA-Z]+ [a-zA-Z]+\.", "", result)
        result = re.sub("[a-zA-Z]+ by [a-zA-Z]+ [a-zA-Z]+", "", result)
        result = re.sub("Page [0-9]", "", result)
        result = re.sub("Updated [0-9]+/[0-9]+/[0-9]+", "", result)
        result = re.sub("Created [0-9]+/[0-9]+/[0-9]+", "", result)
        result = re.sub("AUTHENTICITY CERTIFIED: ([a-zA-Z]+( [a-zA-Z]+)+)", "", result)
        result = result.strip()

        if len(self.params.keys()) != 0:
            if self.params["names"]:
                return "\n".join(str(item) for item in result.split("\n")[3:])
            else:
                return result
